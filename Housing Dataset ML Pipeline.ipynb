# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_selector
from sklearn.compose import make_column_transformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error,r2_score
from math import sqrt

# %%
data=pd.read_csv('Housing.csv')

# %%
data.head(5)
# Out:
#       price  area  bedrooms  bathrooms  stories  ... hotwaterheating airconditioning parking prefarea furnishingstatus
# 0  13300000  7420         4          2        3  ...              no             yes       2      yes        furnished
# 1  12250000  8960         4          4        4  ...              no             yes       3       no        furnished
# 2  12250000  9960         3          2        2  ...              no              no       2      yes   semi-furnished
# 3  12215000  7500         4          2        2  ...              no             yes       3      yes        furnished
# 4  11410000  7420         4          1        2  ...              no             yes       2       no        furnished
#
# [5 rows x 13 columns]

# %%
data.tail(5)
# Out:
#        price  area  bedrooms  bathrooms  stories  ... hotwaterheating airconditioning parking prefarea furnishingstatus
# 540  1820000  3000         2          1        1  ...              no              no       2       no      unfurnished
# 541  1767150  2400         3          1        1  ...              no              no       0       no   semi-furnished
# 542  1750000  3620         2          1        1  ...              no              no       0       no      unfurnished
# 543  1750000  2910         3          1        1  ...              no              no       0       no        furnished
# 544  1750000  3850         3          1        2  ...              no              no       0       no      unfurnished
#
# [5 rows x 13 columns]

# %%
data.isna().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
x=data.drop('price',axis=1)

# %%
x
# Out:
#      area  bedrooms  bathrooms  stories mainroad  ... hotwaterheating airconditioning parking prefarea  furnishingstatus
# 0    7420         4          2        3      yes  ...              no             yes       2      yes         furnished
# 1    8960         4          4        4      yes  ...              no             yes       3       no         furnished
# 2    9960         3          2        2      yes  ...              no              no       2      yes    semi-furnished
# 3    7500         4          2        2      yes  ...              no             yes       3      yes         furnished
# 4    7420         4          1        2      yes  ...              no             yes       2       no         furnished
# ..    ...       ...        ...      ...      ...  ...             ...             ...     ...      ...               ...
# 540  3000         2          1        1      yes  ...              no              no       2       no       unfurnished
# ...

# %%
y=data.price

# %%
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# %%
cat_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),  # Yahan underscore zaroori hai!
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

# %%
transformer = ColumnTransformer([
    ('num', num_pipeline, make_column_selector(dtype_include=np.number)),
    ('cat', cat_pipeline, make_column_selector(dtype_include=object))
])

# %%
model_pipeline = Pipeline([
    ('preprocessing', transformer),
    ('poly', PolynomialFeatures(degree=1, include_bias=True)),
    ('model', LinearRegression())
])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=65)

model_pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x0000020C69BBE7B0>),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
# ...

# %%
y_train_pred=model_pipeline.predict(x_train)

# %%
sqrt(mean_squared_error(y_train,y_train_pred))
# Out:
# 1039931.6012620351

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.6867677344404175

# %%
y_test_pred=model_pipeline.predict(x_test)

# %%
sqrt(mean_squared_error(y_test,y_test_pred))
# Out:
# 1119534.7873009737

# %%
r2_score(y_test,y_test_pred)
# Out:
# 0.6543936113070026

# %%
def make_predictions(model, x_data):
    return model.predict(x_data)

def plot_simple_scatter(y_actual, y_predicted):
    plt.figure(figsize=(7, 5))
    plt.scatter(y_actual, y_predicted, color='blue', alpha=0.6, edgecolors='k', s=50)
    plt.plot([y_actual.min(), y_actual.max()], [y_actual.min(), y_actual.max()], color='red', linestyle='--', lw=2, label='Ideal Line')
    
    plt.xlabel('Actual Prices', fontsize=12)
    plt.ylabel('Predicted Prices', fontsize=12)
    plt.title('House Price Prediction: Actual vs Predicted', fontsize=14)
    plt.legend()
    plt.grid(True, linestyle=':', alpha=0.6)
    plt.show()
y_pred_train = make_predictions(model_pipeline, x_train)
plot_simple_scatter(y_train, y_pred_train)
